# %% [markdown]
# ## Observations and Insights

# %% [markdown]
#  The volume of the tumor decreased the longer mouse x401 was on Capomulin.
#  There were more measurements taken on the drugs Capomulin and Ramicane then the other drugs in the study.
#  There were more male mice used through out study then female mice.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single dataset
mouse_study = pd.merge(mouse_metadata, study_results, on = "Mouse ID", how = "outer")

# Display the data table for preview
mouse_study.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
mouse_study["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# duplicate = mouse_study[mouse_study.duplicated()]
mouse_study[mouse_study.duplicated(['Mouse ID', 'Timepoint'])]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_study[mouse_study['Mouse ID']=='g989']
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean = mouse_study[mouse_study['Mouse ID']!='g989']
clean.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
clean["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

grp = clean.groupby('Drug Regimen')['Tumor Volume (mm3)']
pd.DataFrame({'mean':grp.mean(),'median':grp.median(),'var':grp.var(),'std':grp.std(),'sem':grp.sem()})
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
grp.agg(['mean','median','var','std','sem'])
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

measurements = clean.groupby('Drug Regimen').Timepoint.count()
measurements.plot.bar(rot=0,figsize=(15,6),title='Measurements By Regimen',ylabel='Measurements')
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
plt.figure(figsize=[15,6])
plt.bar(measurements.index, measurements.values)
plt.ylabel('Measurements')
plt.xlabel('Drug Regimen')
plt.title('Measurements By Regimen')
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_groups = clean.groupby("Sex")

gender_count = gender_groups["Mouse ID"].count()

gender_pie = gender_count.plot(kind="pie", y= "Mouse ID", title= "Distribution", autopct='%1.1f%%')
gender_pie.set_ylabel("Mouse ID")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
mylabels = ["Female", "Male"]
plt.pie(gender_count, labels = mylabels, autopct='%1.1f%%')
plt.title("Distribution")
plt.ylabel("Mouse ID")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
mice_max = clean.groupby(["Mouse ID"])["Timepoint"].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mice_max_combined = pd.merge(mice_max, clean, on =("Mouse ID", "Timepoint"), how = "inner")
mice_max_combined
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)
results_dict = {"Capomulin": None, "Ramicane": None, "Infubinol": None, "Ceftamin": None}

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for regimen in results_dict: 

    # Locate the rows which contain mice on each drug and get the tumor volumes
    t_volumes = mice_max_combined.loc[mice_max_combined["Drug Regimen"] == regimen,"Tumor Volume (mm3)"]
    #print(type(t_volumes), t_volumes)
    quartiles = t_volumes.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    mean = quartiles[0.5]
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    results_dict[regimen] = t_volumes
    
    print(f"{regimen}'s lower quartile of Tumor Volume is {lowerq}.")
    print(f"{regimen}'s upper quartile of Tumor Volume is {upperq}.")
    print(f"{regimen}'s interquartile range of Tumor Volume is {iqr}.")
    print(f"{regimen}'s median of Tumor Volume is {mean}.")
    print(f"Values below {lower_bound} and above {upper_bound} could be outliers.")
# Out:
# Capomulin's lower quartile of Tumor Volume is 32.37735684.
# Capomulin's upper quartile of Tumor Volume is 40.1592203.
# Capomulin's interquartile range of Tumor Volume is 7.781863460000004.
# Capomulin's median of Tumor Volume is 38.125164399999996.
# Values below 20.70456164999999 and above 51.83201549 could be outliers.
# Ramicane's lower quartile of Tumor Volume is 31.56046955.
# Ramicane's upper quartile of Tumor Volume is 40.65900627.
# Ramicane's interquartile range of Tumor Volume is 9.098536719999998.
# Ramicane's median of Tumor Volume is 36.56165229.
# Values below 17.912664470000003 and above 54.30681135 could be outliers.
# Infubinol's lower quartile of Tumor Volume is 54.04860769.
# Infubinol's upper quartile of Tumor Volume is 65.52574285.
# Infubinol's interquartile range of Tumor Volume is 11.477135160000003.
# Infubinol's median of Tumor Volume is 60.16518046.
# Values below 36.83290494999999 and above 82.74144559000001 could be outliers.
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
volume_list = [v for k, v in results_dict.items()]
red_diamond = dict(markerfacecolor='r', marker='D')

volfig = plt.figure().subplots()

volfig.boxplot(volume_list, labels=results_dict.keys(), flierprops=red_diamond)

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_mice=clean.loc[clean["Drug Regimen"] == 'Capomulin']

mouse = capomulin_mice.loc[capomulin_mice["Mouse ID"] == 'x401']

mouse_time = mouse["Timepoint"]
mouse_tv = mouse["Tumor Volume (mm3)"]

one_mouse, = plt.plot(mouse_time,mouse_tv)

plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Tumor Volume (mm3) vs Timepoint for mouse x401 on Capomulin")
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_mice=clean.loc[clean["Drug Regimen"] == 'Capomulin']
capomulin_mice = capomulin_mice.set_index("Mouse ID")

for weight in capomulin_mice:
    
    mouse_weight = capomulin_mice.iloc[:,5]
    
    average_tumor = capomulin_mice.iloc[:,6].mean()

capomulin_mice.plot(kind="scatter", x=mouse_weight, y= average_tumor,\
                    title= "Average Tumor Volume vs. Mouse Weight")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-e916a12828f8> in <module>
#       9     average_tumor = capomulin_mice.iloc[:,5].mean()
#      10
# ---> 11 capomulin_mice.plot(kind="scatter", x=mouse_weight, y= average_tumor,\
#      12                     title= "Average Tumor Volume vs. Mouse Weight")
#      13
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     892         if kind in self._dataframe_kinds:
#     893             if isinstance(data, ABCDataFrame):
# --> 894                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     895             else:
#     896                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
# ...

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
